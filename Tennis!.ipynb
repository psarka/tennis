# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pystan import stan
# %matplotlib inline

# %%
df = pd.read_csv('Wimbledon_2013_Sample_Point_by_Point_data.csv')
df = df[df.Event == 'MS']
df = df.drop(['Tournament', 'Year', 'Court', 'Event', 'Round', '1st Serve Timestamp', '2nd Serve Timestamp', 'End of Point Timestamp'], axis=1)
df.rename(columns={'Tiebreak?': 'Tiebreak',
                   'Service (0=Double Fault|1=First Serve|2=Second Serve)': 'Service', 
                   'Speed MPH (where avail)': 'Speed', 
                   'Shot Main (1=FH|2=BH|3=ACE|4=Service Winner|5=Double Fault|6=Other)': 'Main_shot',
                   'Shot Detail (0=None|1=Drive|2=Return|3=Passing|4=Volley|5=Smash|6=Stroke at Net|7=Passing-Volley|8=Drop-Shot|9=Lob|10=Approach|11=Approach-Return)': 'Shot_detail',
                   'Shot Win/Err (0=Undefined|1=Winner|2=Unforced Error|3=Forced Error)': 'Shot_win/err'
                   },inplace=True)
df.Server = df.Server.apply(lambda x: np.int(x[0]))

# %%
df.head(5)
# Out:
#    Match    Player 1 Player 2  Set  Game Tiebreak  Point  Server  Winner  \
# 0  MS101  N.Djokovic  F.Mayer    1     1    False      1       1       1
# 1  MS101  N.Djokovic  F.Mayer    1     1    False      2       1       1
# 2  MS101  N.Djokovic  F.Mayer    1     1    False      3       1       1
# 3  MS101  N.Djokovic  F.Mayer    1     1    False      4       1       1
# 4  MS101  N.Djokovic  F.Mayer    1     2    False      1       2       2
#
#   Score 1  Score 2  Service Serve Direction   S&V? Return Hand  Speed  \
# 0       0        0        1               C  False           B    117
# 1      15        0        2               C  False           F    105
# 2      30        0        1               C  False           B    124
# 3      40        0        2               C  False           F    102
# 4       0        0        2               B  False           B     90
#
#    Main_shot  Shot_detail Rally Count  Shot_win/err
# 0          2            1           5             3
# 1          2            1           3             1
# 2          1            6           3             1
# 3          6            2           1             3
# 4          1            5          17             1

# %%
def f(m):
    s_0, s_1, s_2 = sum(m.Service == 0), sum(m.Service == 1), sum(m.Service == 2)
    
    # Times served 1st serve:
    n_try1 = s_0 + s_1 + s_2
    
    # Times won 1st serve:
    n_win1 = sum((m.Service == 1) & (m.Server == m.Winner))
    
    # MLE probability to win 1st serve:
    p_mle_win1 = n_win1/n_try1
    
    # Times served 2nd serve:
    n_try2 = s_0 + s_2
    
    # Times won 2nd serve:
    n_win2 = sum((m.Service == 2) & (m.Server == m.Winner))
    
    # MLE probability to win 2nd serve
    p_mle_win2 = n_win2/n_try2
        
    return pd.Series({'n_try1': n_try1, 
                      'n_try2': n_try2,
                      'n_win1': n_win1, 
                      'n_win2': n_win2,
                      'p_mle_win1': p_mle_win1,
                      'p_mle_win2': p_mle_win2,
                      })

df = df.groupby(['Match', 'Player 1', 'Player 2', 'Server']).apply(f)
df['p_mle_delta'] = df.p_mle_win2 - df.p_mle_win1
df.sort('p_mle_delta').head()
# Out:
#                                     n_try1  n_try2  n_win1  n_win2  \
# Match Player 1  Player 2    Server
# MS219 J.Isner   A.Mannarino 2            5       1       4       0
# MS311 N.Almagro J.Janowicz  1          107      30      58       8
# MS159 M.Gicquel V.Pospisil  2           88      26      56      11
# MS308 G.Zemlja  J.Del Potro 1          101      33      53      11
# MS214 M.Llodra  A.Seppi     1           36      13      17       4
#
#                                     p_mle_win1  p_mle_win2  p_mle_delta
# Match Player 1  Player 2    Server
# MS219 J.Isner   A.Mannarino 2         0.800000    0.000000    -0.800000
# MS311 N.Almagro J.Janowicz  1         0.542056    0.266667    -0.275389
# MS159 M.Gicquel V.Pospisil  2         0.636364    0.423077    -0.213287
# MS308 G.Zemlja  J.Del Potro 1         0.524752    0.333333    -0.191419
# MS214 M.Llodra  A.Seppi     1         0.472222    0.307692    -0.164530

# %%
def f(x):
    return list(x.values.astype(np.int))

stan_data = {'N': len(df), 
             'try1': f(df.n_try1), 'try2': f(df.n_try2),
             'win1': f(df.n_win1), 'win2': f(df.n_win2)}

stan_code = '''
data {
    int<lower=1> N;
    int try1[N];
    int try2[N];
    int win1[N];
    int win2[N];
}
parameters {
    real<lower=0,upper=1> phi1;
    real<lower=0,upper=1> phi2;
    real<lower=0.1> lambda1;
    real<lower=0.1> lambda2;
    vector<lower=0,upper=1>[N] theta1;
    vector<lower=0,upper=1>[N] theta2;
}
transformed parameters {
    real<lower=0> alpha1;
    real<lower=0> alpha2;
    real<lower=0> beta1;
    real<lower=0> beta2;
    alpha1 <- lambda1*phi1;
    alpha2 <- lambda2*phi2;
    beta1 <- lambda1*(1-phi1);
    beta2 <- lambda2*(1-phi2);
}
model {
    phi1 ~ beta(1,1);
    phi2 ~ beta(1,1);
    lambda1 ~ pareto(0.1, 1.5);
    lambda2 ~ pareto(0.1, 1.5);
    
    for (i in 1:N) {
        theta1[i] ~ beta(alpha1, beta1);
        theta2[i] ~ beta(alpha2, beta2);
        win1[i] ~ binomial(try1[i], theta1[i]);
        win2[i] ~ binomial(try2[i], theta2[i]);
    }
}
generated quantities {
    vector[N] delta;
    for (i in 1:N)
        delta[i] <- theta1[i] - theta2[i];
}
'''

# %%
fit = stan(model_code=stan_code, data=stan_data)

# %%
fit.traceplot(['beta1'])

# %%
# show a traceplot of ALL parameters. This is a bear if you have many
fit.traceplot()
py.show()
 
# Instead, show a traceplot for single parameter
fit.plot(['a'])
py.show()
 
##### PREDICTION ####
 
# make a dataframe of parameter estimates for all chains
params = pd.DataFrame({'a': fit.extract('a', permuted=True), 'b': fit.extract('b', permuted=True)})
 
# next, make a prediction function. Making a function makes every step following this 10 times easier
def stanPred(p):
 fitted = p[0] + p[1] * predX
 return pd.Series({'fitted': fitted})
 
# make a prediction vector (the values of X for which you want to predict)
predX = np.arange(1, 100)
 
# get the median parameter estimates
medParam = params.median()
# predict
yhat = stanPred(medParam)
 
# get the predicted values for each chain. This is super convenient in pandas because
# it is possible to have a single column where each element is a list
chainPreds = params.apply(stanPred, axis = 1)
 
## PLOTTING
 
# create a random index for chain sampling
idx = np.random.choice(1999, 50)
# plot each chain. chainPreds.iloc[i, 0] gets predicted values from the ith set of parameter estimates
for i in range(len(idx)):
 py.plot(predX, chainPreds.iloc[idx[i], 0], color='lightgrey')
 
# original data
py.plot(x, y, 'ko')
# fitted values
py.plot(predX, yhat['fitted'], 'k')
 
# supplementals
py.xlabel('X')
py.ylabel('Y')
 
py.show()

# %%
# make a function that iterates over every predicted values in every chain and returns the quantiles. For example:
 
def quantileGet(q):
    # make a list to store the quantiles
    quants = []
 
    # for every predicted value
    for i in range(len(predX)):
        # make a vector to store the predictions from each chain
        val = []
 
        # next go down the rows and store the values
        for j in range(chainPreds.shape[0]):
            val.append(chainPreds['fitted'][j][i])
 
        # return the quantile for the predictions.
        quants.append(np.percentile(val, q))
 
    return quants
 
# NOTE THAT NUMPY DOES PERCENTILES, SO MULTIPLE QUANTILE BY 100
# 2.5% quantile
lower = quantileGet(2.5)
#97.5
upper = quantileGet(97.5)
 
# plot this
fig = py.figure()
ax = fig.add_subplot(111)
 
# shade the credible interval
ax.fill_between(predX, lower, upper, facecolor = 'lightgrey', edgecolor = 'none')
# plot the data
ax.plot(x, y, 'ko')
# plot the fitted line
ax.plot(predX, yhat['fitted'], 'k')
 
# supplementals
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.grid()
 
py.show()
